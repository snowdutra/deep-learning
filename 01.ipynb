# %%
np.random.seed(42)  # Fixar seed: resultados reproduzíveis (conceito: reprodutibilidade)

N = 1000            # Número de amostras (dataset grande)
D = 4               # Número de features (entradas)

X = np.random.randn(N, D)


true_W = np.array([[3.0], [-2.0], [1.5], [0.5]])


true_b = np.array([[1.0]])


noise = 0.5 * np.random.randn(N, 1)


y = X.dot(true_W) + true_b + noise

print("Shape de X:", X.shape)  # (1000, 4)
print("Shape de y:", y.shape)  # (1000, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 np.random.seed(42)  # Fixar seed: resultados reproduzíveis (conceito: reprodutibilidade)
#       3 N = 1000            # Número de amostras (dataset grande)
#       4 D = 4               # Número de features (entradas)
#
# NameError: name 'np' is not defined

# %%
W = np.random.randn(D, 1) 
b = np.zeros((1, 1))

lr = 0.01
epochs = 2000

for epoch in range(epochs):
    y_hat = X.dot(W) + b

    error = y_hat - y

    loss = np.mean(error ** 2)

    dL_dyhat = (2/N) * error
    dL dW = X.T.dot(dL_dyhat)
