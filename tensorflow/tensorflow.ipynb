# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\gustavo.telles\AppData\Roaming\Python\Python313\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\Users\gustavo.telles\AppData\Roaming\Python\Python313\site-packages (from tensorflow) (6.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in C:\Users\gustavo.telles\AppData\Roaming\Python\Python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\gustavo.telles\AppData\Roaming\Python\Python313\site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\gustavo.telles\AppData\Roaming\Python\Python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\gustavo.telles\AppData\Roaming\Python\Python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\gustavo.telles\AppData\Roaming\Python\Python313\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
X = np.array([[0,0], [0,1], [1,0], [1,1]])
X
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
y = np.array([[1], [0], [0], [1]])
y
# Out:
# array([[1],
#        [0],
#        [0],
#        [1]])

# %%
neuronios_entrada = 2
neuronios_oculta = 3
neuronios_saida = 1

# %%
W = {'oculta': tf.Variable(tf.random.normal([neuronios_entrada, neuronios_oculta]), name = 'w_oculta'),
     'saida': tf.Variable(tf.random.normal([neuronios_oculta, neuronios_saida]), name = 'w_saida')}

# %%
type(W)
type(W['oculta'])
W['oculta']
W['saida']
# Out:
# <tf.Variable 'w_saida_3:0' shape=(3, 1) dtype=float32_ref>

# %%
b = {'oculta': tf.Variable(tf.random.normal([neuronios_oculta]), name = 'b_oculta'),
     'saida': tf.Variable(tf.random.normal([neuronios_saida]), name = 'b_saida')}

# %%
xph = tf.placeholder(tf.float32, [4, neuronios_entrada], name = 'xph')
yph = tf.placeholder(tf.float32, shape= [4, neuronios_saida], name = 'yph')

# %%
camada_oculta = tf.add(tf.matmul(xph, W['oculta']), b['oculta'])
camada_oculta_ativacao = tf.sigmoid(camada_oculta)
camada_saida = tf.add(tf.matmul(camada_oculta_ativacao, W['saida']), b['saida'])
camada_saida_ativacao = tf.sigmoid(camada_saida)
erro = tf.losses.mean_squared_error(yph, camada_saida_ativacao)
otimizador = tf.train.GradientDescentOptimizer(learning_rate = 0.3).minimize(erro)
# Out:
# WARNING:tensorflow:From C:\Users\gustavo.telles\AppData\Local\Temp\ipykernel_10188\2920773294.py:5: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From C:\Users\gustavo.telles\AppData\Local\Temp\ipykernel_10188\2920773294.py:6: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %%
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    for epocas in range(10000):
        erro_medio = 0
        _, custo = sess.run([otimizador, erro], feed_dict = {xph: X, yph: y})
        if epocas % 200 == 0:
            erro_medio += custo / 4
            print(erro_medio)
    W_final, b_final = sess.run([W, b])
# Out:
# 0.076557234
# 0.06086927
# 0.057914257
# 0.053040817
# 0.045984037
# 0.037649654
# 0.02851941
# 0.020088036
# 0.013877768
# 0.009855308
# 0.0073115095
# 0.0056586256
# 0.004538732
# 0.0037475517
# 0.0031674134
# 0.0027282448
# 0.0023867006
# 0.0021149272
# 0.0018944091
# 0.0017124707
# 0.0015601789
# 0.0014310861
# 0.0013204518
# 0.0012247084
# 0.001141134
# 0.0010676185
# 0.0010025016
# 0.0009444613
# 0.00089244044
# 0.00084556884
# 0.0008031405
# 0.0007645673
# 0.0007293613
# 0.0006971102
# 0.00066746527
# 0.00064013025
# 0.00061485224
# 0.00059141195
# 0.00056962
# 0.00054931256
# 0.00053034705
# 0.00051259703
# 0.00049595145
# 0.0004803121
# 0.00046559316
# 0.0004517152
# 0.00043861225
# 0.00042622112
# 0.00041448575
# 0.00040335784

# %%
W_final
# Out:
# {'oculta': array([[-3.1022608,  6.2368517,  5.456162 ],
#         [ 6.1162   , -2.9078715,  5.4159117]], dtype=float32),
#  'saida': array([[ 7.048073],
#         [ 7.021651],
#         [-8.531138]], dtype=float32)}
