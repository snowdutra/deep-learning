# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zalando-research/fashionmnist")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("C:/Users/gustavo.telles/Desktop/deep-learning/cnn")
#       6 print("Path to dataset files:", path)
#
# File c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages\kagglehub\datasets.py:50, in dataset_download(handle, path, force_download, output_dir)
#      34 def dataset_download(
#      35     handle: str,
#      36     path: str | None = None,
#    (...)     39     output_dir: str | None = None,
#      40 ) -> str:
#      41     """Download dataset files
#      42     Args:
#      43         handle: (string) the dataset handle
#    (...)     48         A string requesting the path to the requested dataset files.
#      49     """
# ---> 50     h = parse_dataset_handle(handle)
#      51     logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
#      52     resolved_path, _ = registry.dataset_resolver(
#      53         h,
#      54         path,
#      55         force_download=force_download,
#      56         output_dir=output_dir,
#      57     )
#
# File c:\Users\gustavo.telles\AppData\Local\Programs\Python\Python313\Lib\site-packages\kagglehub\handle.py:166, in parse_dataset_handle(handle)
#     159     return DatasetHandle(
#     160         owner=parts[0],
#     161         dataset=parts[1],
#     162         version=None,
#     163     )
#     165 msg = f"Invalid dataset handle: {handle}"
# --> 166 raise ValueError(msg)
#
# ValueError: Invalid dataset handle: C:/Users/gustavo.telles/Desktop/deep-learning/cnn
